# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Parts of EDA
#
# 1. Univariate Analysis ==> Analysis on a single Independent column
#
# 2. Bivariate Analysis ==> Analysis on two columns
#
# 3. Multivariate Analysis ==> Analysis on more than 2 columns

# %%
# !pip install matplotlib

# %%
# !pip install seaborn

# %% [raw]
# import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\kumaw\\OneDrive\\Desktop\\python\\Titanic-Dataset.csv")

# %%
sns.countplot(x = df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind = 'bar' )
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind = 'pie' , autopct ='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(x=df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # 3. Boxplot
#
# # for find our outliers
#
# #1. Lower fence
#
# #2. 25% data
#
# #3. IQR(Inter Quartile Range) (75%-25%)
#
# #4. 75% data
#
# #5. upper fence
#
# # x = 1,2,3,4,5
#
# #mean = (1+2+3+4+5)/5 = 15/5 = 3
#
# ### HERE 100 IS OUTLIER
#
# #x = 1,2,3,4,5,100
#
# #mean 15+100/6 115/6 = 19.3

# %%
sns.boxplot(x = df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Bivariate Analysis

# %%
# 1. scatterploat(

# %%
sns.scatterplot(x = tips['total_bill'],
                y = tips['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = tips, hue = tips['sex'] )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = tips, hue = tips['sex'], style = tips['smoker'] )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
p = pd.crosstab(tips['day'], tips['time'])

# %%
p
# Out:
# time  Lunch  Dinner
# day
# Thur     61       1
# Fri       7      12
# Sat       0      87
# Sun       0      76

# %%
sns.heatmap(p)
# Out:
# <Axes: xlabel='time', ylabel='day'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df1 = df.drop(columns = ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked' ])
df1 = df1.dropna()

# %%
((df1.groupby('Pclass').mean() ['Survived'])*100).plot(kind= 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='Survived'>

# %%
df.to_csv("data.csv", index=False)

# %%
df3 = pd.read_csv("data.csv")

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df3.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df3.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df3.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df3.sample(3)
# Out:
#      PassengerId  Survived  Pclass                        Name   Sex   Age  \
# 562          563         0       2  Norman, Mr. Robert Douglas  male  28.0
# 342          343         0       2  Collander, Mr. Erik Gustaf  male  28.0
# 324          325         0       3    Sage, Mr. George John Jr  male   NaN
#
#      SibSp  Parch    Ticket   Fare Cabin Embarked
# 562      0      0    218629  13.50   NaN        S
# 342      0      0    248740  13.00   NaN        S
# 324      8      2  CA. 2343  69.55   NaN        S

# %%
df3.shape
# Out:
# (891, 12)

# %%
df3.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df3['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Parch'][1]=1
# Out:
# C:\Users\kumaw\AppData\Local\Temp\ipykernel_15292\2168754023.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Parch'][1]=1
# C:\Users\kumaw\AppData\Local\Temp\ipykernel_15292\2168754023.py:1: SettingWithCopyWarning:
# ...

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3['Name'].value_counts()
# Out:
# Name
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: count, Length: 891, dtype: int64

# %%
df3.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df3 = df3.dropna()

# %%
df3.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
df4 = df3.iloc[4, :3]
df4
# Out:
# PassengerId    12
# Survived        1
# Pclass          1
# Name: 11, dtype: object

# %%
df3.loc[1:3 , ['Age' , 'Survived']]
# Out:
#     Age  Survived
# 1  38.0         1
# 3  35.0         1

# %%
p = df3.dtypes
p
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
i = df3.ndim
i
# Out:
# 2

# %%
a = df3.values
a
# Out:
# array([[2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [4, 1, 1, ..., 53.1, 'C123', 'S'],
#        [7, 0, 1, ..., 51.8625, 'E46', 'S'],
#        ...,
#        [880, 1, 1, ..., 83.1583, 'C50', 'C'],
#        [888, 1, 1, ..., 30.0, 'B42', 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C']], dtype=object)

# %%
g = df3.sort_values(by = 'Age')
g
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 305          306         1       1        Allison, Master. Hudson Trevor
# 183          184         1       2             Becker, Master. Richard F
# 205          206         0       3            Strom, Miss. Telma Matilda
# 297          298         0       1          Allison, Miss. Helen Loraine
# 340          341         1       2        Navratil, Master. Edmond Roger
# ..           ...       ...     ...                                   ...
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 456          457         0       1             Millet, Mr. Francis Davis
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 96            97         0       1             Goldschmidt, Mr. George B
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#         Sex    Age  SibSp  Parch     Ticket      Fare    Cabin Embarked
# ...

# %%
df3['Age'] =df3['Age'].add(4)
# Out:
# C:\Users\kumaw\AppData\Local\Temp\ipykernel_15292\1349865856.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Age'] =df3['Age'].add(4)

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  42.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  39.0      1
# 6                              McCarthy, Mr. Timothy J    male  58.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   8.0      1
# 11                            Bonnell, Miss. Elizabeth  female  62.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = df3.count()
s
# Out:
# PassengerId    183
# Survived       183
# Pclass         183
# Name           183
# Sex            183
# Age            183
# SibSp          183
# Parch          183
# Ticket         183
# Fare           183
# Cabin          183
# Embarked       183
# dtype: int64

# %%
p = df3.max()
p
# Out:
# PassengerId                         890
# Survived                              1
# Pclass                                3
# Name           Young, Miss. Marie Grice
# Sex                                male
# Age                                84.0
# SibSp                                 3
# Parch                                 4
# Ticket                        WE/P 5735
# Fare                           512.3292
# Cabin                                 T
# Embarked                              S
# dtype: object

# %%
h = df3.min()
h
# Out:
# PassengerId                                2
# Survived                                   0
# Pclass                                     1
# Name           Allen, Miss. Elisabeth Walton
# Sex                                   female
# Age                                     4.92
# SibSp                                      0
# Parch                                      0
# Ticket                                110152
# Fare                                     0.0
# Cabin                                    A10
# Embarked                                   C
# dtype: object

# %%
r = df3['Age'].mean()
r
# Out:
# 39.6744262295082

# %%
g = df3.filter(items = ['Age', 'Survived'])
g
# Out:
#       Age  Survived
# 1    42.0         1
# 3    39.0         1
# 6    58.0         0
# 10    8.0         1
# 11   62.0         1
# ..    ...       ...
# 871  51.0         1
# 872  37.0         0
# 879  60.0         1
# 887  23.0         1
# 889  30.0         1
#
# [183 rows x 2 columns]

# %%
df3['half'] = df3['Age'].where(df3['Age']>40, other =0)
df3.head(10)
# Out:
# C:\Users\kumaw\AppData\Local\Temp\ipykernel_15292\2113072933.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['half'] = df3['Age'].where(df3['Age']>40, other =0)
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
# 23           24         1       1
# 27           28         0       1
# 52           53         1       1
# 54           55         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  42.0      1
# ...
